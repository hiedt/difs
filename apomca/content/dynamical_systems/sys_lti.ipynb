# %% [markdown]
# # Linearity and Time Variance
#
# ## Linearity
#
# ## Time Variance
#
# ```{note} Linear Time-invariant (LTI)
# :name: lti
#
# As a first course in the field, most undegraduate textbooks only deal with LTI systems. They are easy, yet fundamental.
# ```
