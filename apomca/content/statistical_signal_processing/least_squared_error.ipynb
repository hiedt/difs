# %% [markdown]
# # Linear Least Squared Error
#
# Also known as *linear regression*, (linear) least squared error (LSE) has been talked about too much by many authors before so I will not reiterate it here. Instead, more advanced variants: weighted LSE, constraint LSE, and sequential LSE will be discussed.
